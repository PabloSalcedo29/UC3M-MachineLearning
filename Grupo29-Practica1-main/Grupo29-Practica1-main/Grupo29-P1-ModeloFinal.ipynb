# %%
import pandas as pd
import joblib

# %%
datos_comp = pd.read_csv("comp_st29ns1.txt.bz2", compression="bz2", index_col=0)
datos_comp
# Out:
#        apcp_sf1_1  apcp_sf2_1  apcp_sf3_1  apcp_sf4_1  apcp_sf5_1  dlwrf_s1_1  \
# V4381    0.000000    0.000000    0.000000         0.0         0.0  268.859539
# V4382    0.000000    0.000000    0.000000         0.0         0.0  277.566831
# V4383    0.000000    0.000000    0.000000         0.0         0.0  258.547630
# V4384    0.000000    0.000909    0.000909         0.0         0.0  288.658428
# V4385    0.000000    0.000000    0.000000         0.0         0.0  290.228657
# ...           ...         ...         ...         ...         ...         ...
# V5109    0.000000    0.000000    0.000000         0.0         0.0  235.564081
# V5110    0.497273    0.000000    0.000000         0.0         0.0  296.437503
# V5111    0.000000    0.000000    0.000000         0.0         0.0  225.723744
# V5112    0.075455    0.000000    0.000000         0.0         0.0  281.388225
# V5113    0.000000    0.000000    0.000000         0.0         0.0  247.577497
#
# ...

# %%
import joblib
modelo_final = joblib.load('modelo_final.pkl')

predicciones_final = pd.DataFrame(modelo_final.predict(datos_comp), columns=['Salida'])
predicciones_final.to_csv('Predicciones_modelo_final.csv', index=False)
# Out:
#          Salida
# 0    14003346.0
# 1    13815306.0
# 2    14003346.0
# 3    13815306.0
# 4    13815306.0
# ..          ...
# 728  14003346.0
# 729  14003346.0
# 730  14003346.0
# 731  14003346.0
# 732  14003346.0
#
# [733 rows x 1 columns]
